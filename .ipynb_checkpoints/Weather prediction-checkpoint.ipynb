# %%
import pandas as pd

weather = pd.read_csv("weather.csv", index_col="DATE")

# %%
weather
# Out:
#                 STATION                      NAME  PRCP  TAVG   TMAX  TMIN
# DATE
# 2000-01-01  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    71   82.0  60.0
# 2000-01-02  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    68   81.0   NaN
# 2000-01-03  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    67   83.0   NaN
# 2000-01-04  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    69   83.0  53.0
# 2000-01-05  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    69   83.0  55.0
# ...                 ...                       ...   ...   ...    ...   ...
# 2024-04-29  IN001080500  BEGUMPET OBSERVATORY, IN   NaN    97  107.0  85.0
# 2024-04-30  IN001080500  BEGUMPET OBSERVATORY, IN   NaN    98    NaN  83.0
# 2024-05-02  IN001080500  BEGUMPET OBSERVATORY, IN   NaN    95  109.0   NaN
# 2024-05-03  IN001080500  BEGUMPET OBSERVATORY, IN   NaN    97    NaN  81.0
# 2024-05-04  IN001080500  BEGUMPET OBSERVATORY, IN   NaN    97  110.0  83.0
#
# [8880 rows x 6 columns]

# %%
null_pct = weather.apply(pd.isnull).sum()/weather.shape[0]

# %%
weather.apply(pd.isnull).sum()
# Out:
# STATION       0
# NAME          0
# PRCP       5466
# TAVG          0
# TMAX       2039
# TMIN       3123
# dtype: int64

# %%
null_pct
# Out:
# STATION    0.000000
# NAME       0.000000
# PRCP       0.615541
# TAVG       0.000000
# TMAX       0.229617
# TMIN       0.351689
# dtype: float64

# %%
weather
# Out:
#                 STATION                      NAME  PRCP  TAVG   TMAX  TMIN
# DATE
# 2000-01-01  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    71   82.0  60.0
# 2000-01-02  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    68   81.0   NaN
# 2000-01-03  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    67   83.0   NaN
# 2000-01-04  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    69   83.0  53.0
# 2000-01-05  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    69   83.0  55.0
# ...                 ...                       ...   ...   ...    ...   ...
# 2024-04-29  IN001080500  BEGUMPET OBSERVATORY, IN   NaN    97  107.0  85.0
# 2024-04-30  IN001080500  BEGUMPET OBSERVATORY, IN   NaN    98    NaN  83.0
# 2024-05-02  IN001080500  BEGUMPET OBSERVATORY, IN   NaN    95  109.0   NaN
# 2024-05-03  IN001080500  BEGUMPET OBSERVATORY, IN   NaN    97    NaN  81.0
# 2024-05-04  IN001080500  BEGUMPET OBSERVATORY, IN   NaN    97  110.0  83.0
#
# [8880 rows x 6 columns]

# %%
weather.columns = weather.columns.str.lower()

# %%
weather
# Out:
#                 station                      name  prcp  tavg   tmax  tmin
# DATE
# 2000-01-01  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    71   82.0  60.0
# 2000-01-02  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    68   81.0   NaN
# 2000-01-03  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    67   83.0   NaN
# 2000-01-04  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    69   83.0  53.0
# 2000-01-05  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    69   83.0  55.0
# ...                 ...                       ...   ...   ...    ...   ...
# 2024-04-29  IN001080500  BEGUMPET OBSERVATORY, IN   NaN    97  107.0  85.0
# 2024-04-30  IN001080500  BEGUMPET OBSERVATORY, IN   NaN    98    NaN  83.0
# 2024-05-02  IN001080500  BEGUMPET OBSERVATORY, IN   NaN    95  109.0   NaN
# 2024-05-03  IN001080500  BEGUMPET OBSERVATORY, IN   NaN    97    NaN  81.0
# 2024-05-04  IN001080500  BEGUMPET OBSERVATORY, IN   NaN    97  110.0  83.0
#
# [8880 rows x 6 columns]

# %%
weather = weather.ffill()

# %%
weather.apply(pd.isnull).sum()
# Out:
# station    0
# name       0
# prcp       0
# tavg       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.dtypes
# Out:
# station     object
# name        object
# prcp       float64
# tavg         int64
# tmax       float64
# tmin       float64
# dtype: object

# %%
weather.index
# Out:
# Index(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04', '2000-01-05',
#        '2000-01-06', '2000-01-07', '2000-01-08', '2000-01-09', '2000-01-10',
#        ...
#        '2024-04-24', '2024-04-25', '2024-04-26', '2024-04-27', '2024-04-28',
#        '2024-04-29', '2024-04-30', '2024-05-02', '2024-05-03', '2024-05-04'],
#       dtype='object', name='DATE', length=8880)

# %%
weather.index = pd.to_datetime(weather.index)

# %%
weather.index
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10',
#                ...
#                '2024-04-24', '2024-04-25', '2024-04-26', '2024-04-27',
#                '2024-04-28', '2024-04-29', '2024-04-30', '2024-05-02',
#                '2024-05-03', '2024-05-04'],
#               dtype='datetime64[ns]', name='DATE', length=8880, freq=None)

# %%
weather.index.year.value_counts().sort_index()
# Out:
# 2000    366
# 2001    365
# 2002    364
# 2003    364
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    362
# 2022    365
# 2023    365
# 2024    119
# Name: DATE, dtype: int64

# %%
weather["tavg"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather
# Out:
#                 station                      name  prcp  tavg   tmax  tmin
# DATE
# 2000-01-01  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    71   82.0  60.0
# 2000-01-02  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    68   81.0  60.0
# 2000-01-03  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    67   83.0  60.0
# 2000-01-04  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    69   83.0  53.0
# 2000-01-05  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    69   83.0  55.0
# ...                 ...                       ...   ...   ...    ...   ...
# 2024-04-29  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    97  107.0  85.0
# 2024-04-30  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    98  107.0  83.0
# 2024-05-02  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    95  109.0  83.0
# 2024-05-03  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    97  109.0  81.0
# 2024-05-04  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    97  110.0  83.0
#
# [8880 rows x 6 columns]

# %%
weather["target"] = weather.shift(-1)["tmax"]

# %%
weather
# Out:
#                 station                      name  prcp  tavg   tmax  tmin  \
# DATE
# 2000-01-01  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    71   82.0  60.0
# 2000-01-02  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    68   81.0  60.0
# 2000-01-03  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    67   83.0  60.0
# 2000-01-04  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    69   83.0  53.0
# 2000-01-05  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    69   83.0  55.0
# ...                 ...                       ...   ...   ...    ...   ...
# 2024-04-29  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    97  107.0  85.0
# 2024-04-30  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    98  107.0  83.0
# 2024-05-02  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    95  109.0  83.0
# 2024-05-03  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    97  109.0  81.0
# 2024-05-04  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    97  110.0  83.0
#
#             target
# DATE
# 2000-01-01    81.0
# 2000-01-02    83.0
# 2000-01-03    83.0
# 2000-01-04    83.0
# 2000-01-05    83.0
# ...            ...
# 2024-04-29   107.0
# 2024-04-30   109.0
# 2024-05-02   109.0
# 2024-05-03   110.0
# 2024-05-04     NaN
#
# [8880 rows x 7 columns]

# %%
weather = weather.ffill()

# %%
weather
# Out:
#                 station                      name  prcp  tavg   tmax  tmin  \
# DATE
# 2000-01-01  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    71   82.0  60.0
# 2000-01-02  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    68   81.0  60.0
# 2000-01-03  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    67   83.0  60.0
# 2000-01-04  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    69   83.0  53.0
# 2000-01-05  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    69   83.0  55.0
# ...                 ...                       ...   ...   ...    ...   ...
# 2024-04-29  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    97  107.0  85.0
# 2024-04-30  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    98  107.0  83.0
# 2024-05-02  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    95  109.0  83.0
# 2024-05-03  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    97  109.0  81.0
# 2024-05-04  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    97  110.0  83.0
#
#             target
# DATE
# 2000-01-01    81.0
# 2000-01-02    83.0
# 2000-01-03    83.0
# 2000-01-04    83.0
# 2000-01-05    83.0
# ...            ...
# 2024-04-29   107.0
# 2024-04-30   109.0
# 2024-05-02   109.0
# 2024-05-03   110.0
# 2024-05-04   110.0
#
# [8880 rows x 7 columns]

# %%
from sklearn.linear_model import Ridge

rr = Ridge(alpha=.1)

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])]

# %%
predictors
# Out:
# Index(['prcp', 'tavg', 'tmax', 'tmin'], dtype='object')

# %%
def backtest(weather, model, predcitors, start=3650, step=90):
    all_predictions = []
    
    for i in range(start, weather.shape[0], step):
        train = weather.iloc[:i,:]
        test = weather.iloc[i:(i+step),:]
        
        model.fit(train[predictors], train["target"])
        
        preds = model.predict(test[predictors])
        
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
        
        combined.columns = ["actual", "prediction"]
        
        combined["diff"] = (combined["prediction"] - combined["actual"]).abs()
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(weather, rr, predictors)

# %%
predictions
# Out:
#             actual  prediction      diff
# DATE
# 2009-12-31    84.0   85.874243  1.874243
# 2010-01-01    85.0   84.063306  0.936694
# 2010-01-02    87.0   85.200817  1.799183
# 2010-01-03    90.0   85.448258  4.551742
# 2010-01-04    88.0   88.950729  0.950729
# ...            ...         ...       ...
# 2024-04-29   107.0  106.698844  0.301156
# 2024-04-30   109.0  107.141080  1.858920
# 2024-05-02   109.0  107.681209  1.318791
# 2024-05-03   110.0  108.428963  1.571037
# 2024-05-04   110.0  109.020587  0.979413
#
# [5230 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 1.4920019552868555

# %%
predictions["diff"].mean()
# Out:
# 1.4920019552868555

# %%
def pct_diff(old, new):
    return (new-old) / old

def compute_rolling(weather, horizon, col):
    label = f"rolling_{horizon}_{col}"
    
    weather[label] = weather[col].rolling(horizon).mean()
    weather[f"{label}_pct"] = pct_diff(weather[label], weather[col])
    return weather

rolling_horizons = [3,14]

for horizon in rolling_horizons:
    for col in ["tmax", "tmin", "prcp"]:
        weather = compute_rolling(weather, horizon, col)

# %%
weather
# Out:
#                 station                      name  prcp  tavg   tmax  tmin  \
# DATE
# 2000-01-01  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    71   82.0  60.0
# 2000-01-02  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    68   81.0  60.0
# 2000-01-03  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    67   83.0  60.0
# 2000-01-04  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    69   83.0  53.0
# 2000-01-05  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    69   83.0  55.0
# ...                 ...                       ...   ...   ...    ...   ...
# 2024-04-29  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    97  107.0  85.0
# 2024-04-30  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    98  107.0  83.0
# 2024-05-02  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    95  109.0  83.0
# 2024-05-03  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    97  109.0  81.0
# 2024-05-04  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    97  110.0  83.0
#
#             target  rolling_3_tmax  rolling_3_tmax_pct  rolling_3_tmin  \
# DATE
# 2000-01-01    81.0             NaN                 NaN             NaN
# 2000-01-02    83.0             NaN                 NaN             NaN
# 2000-01-03    83.0       82.000000            0.012195       60.000000
# 2000-01-04    83.0       82.333333            0.008097       57.666667
# 2000-01-05    83.0       83.000000            0.000000       56.000000
# ...            ...             ...                 ...             ...
# 2024-04-29   107.0      107.666667           -0.006192       84.000000
# 2024-04-30   109.0      107.333333           -0.003106       84.000000
# 2024-05-02   109.0      107.666667            0.012384       83.666667
# 2024-05-03   110.0      108.333333            0.006154       82.333333
# 2024-05-04   110.0      109.333333            0.006098       82.333333
#
#             rolling_3_tmin_pct  rolling_3_prcp  rolling_3_prcp_pct  \
# DATE
# 2000-01-01                 NaN             NaN                 NaN
# 2000-01-02                 NaN             NaN                 NaN
# 2000-01-03            0.000000             0.0                 NaN
# 2000-01-04           -0.080925             0.0                 NaN
# 2000-01-05           -0.017857             0.0                 NaN
# ...                        ...             ...                 ...
# 2024-04-29            0.011905             0.0                 NaN
# 2024-04-30           -0.011905             0.0                 NaN
# 2024-05-02           -0.007968             0.0                 NaN
# 2024-05-03           -0.016194             0.0                 NaN
# 2024-05-04            0.008097             0.0                 NaN
#
#             rolling_14_tmax  rolling_14_tmax_pct  rolling_14_tmin  \
# DATE
# 2000-01-01              NaN                  NaN              NaN
# 2000-01-02              NaN                  NaN              NaN
# 2000-01-03              NaN                  NaN              NaN
# 2000-01-04              NaN                  NaN              NaN
# 2000-01-05              NaN                  NaN              NaN
# ...                     ...                  ...              ...
# 2024-04-29       102.571429             0.043175        81.142857
# 2024-04-30       103.500000             0.033816        81.357143
# 2024-05-02       104.571429             0.042350        81.571429
# 2024-05-03       105.642857             0.031778        81.642857
# 2024-05-04       106.000000             0.037736        81.642857
#
#             rolling_14_tmin_pct  rolling_14_prcp  rolling_14_prcp_pct
# DATE
# 2000-01-01                  NaN              NaN                  NaN
# 2000-01-02                  NaN              NaN                  NaN
# 2000-01-03                  NaN              NaN                  NaN
# 2000-01-04                  NaN              NaN                  NaN
# 2000-01-05                  NaN              NaN                  NaN
# ...                         ...              ...                  ...
# 2024-04-29             0.047535         0.002857                 -1.0
# 2024-04-30             0.020193         0.002857                 -1.0
# 2024-05-02             0.017513         0.002857                 -1.0
# 2024-05-03            -0.007874         0.002857                 -1.0
# 2024-05-04             0.016623         0.000714                 -1.0
#
# [8880 rows x 19 columns]

# %%
weather = weather.iloc[14:,:]

# %%
weather
# Out:
#                 station                      name  prcp  tavg   tmax  tmin  \
# DATE
# 2000-01-15  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    76   91.0  64.0
# 2000-01-16  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    76   88.0  66.0
# 2000-01-17  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    76   88.0  66.0
# 2000-01-18  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    74   90.0  61.0
# 2000-01-19  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    78   89.0  63.0
# ...                 ...                       ...   ...   ...    ...   ...
# 2024-04-29  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    97  107.0  85.0
# 2024-04-30  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    98  107.0  83.0
# 2024-05-02  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    95  109.0  83.0
# 2024-05-03  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    97  109.0  81.0
# 2024-05-04  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    97  110.0  83.0
#
#             target  rolling_3_tmax  rolling_3_tmax_pct  rolling_3_tmin  \
# DATE
# 2000-01-15    88.0       90.333333            0.007380       64.000000
# 2000-01-16    88.0       89.666667           -0.018587       64.666667
# 2000-01-17    90.0       89.000000           -0.011236       65.333333
# 2000-01-18    89.0       88.666667            0.015038       64.333333
# 2000-01-19    91.0       89.000000            0.000000       63.333333
# ...            ...             ...                 ...             ...
# 2024-04-29   107.0      107.666667           -0.006192       84.000000
# 2024-04-30   109.0      107.333333           -0.003106       84.000000
# 2024-05-02   109.0      107.666667            0.012384       83.666667
# 2024-05-03   110.0      108.333333            0.006154       82.333333
# 2024-05-04   110.0      109.333333            0.006098       82.333333
#
#             rolling_3_tmin_pct  rolling_3_prcp  rolling_3_prcp_pct  \
# DATE
# 2000-01-15            0.000000             0.0                 NaN
# 2000-01-16            0.020619             0.0                 NaN
# 2000-01-17            0.010204             0.0                 NaN
# 2000-01-18           -0.051813             0.0                 NaN
# 2000-01-19           -0.005263             0.0                 NaN
# ...                        ...             ...                 ...
# 2024-04-29            0.011905             0.0                 NaN
# 2024-04-30           -0.011905             0.0                 NaN
# 2024-05-02           -0.007968             0.0                 NaN
# 2024-05-03           -0.016194             0.0                 NaN
# 2024-05-04            0.008097             0.0                 NaN
#
#             rolling_14_tmax  rolling_14_tmax_pct  rolling_14_tmin  \
# DATE
# 2000-01-15        85.071429             0.069689        57.928571
# 2000-01-16        85.571429             0.028381        58.357143
# 2000-01-17        85.928571             0.024106        58.785714
# 2000-01-18        86.428571             0.041322        59.357143
# 2000-01-19        86.857143             0.024671        59.928571
# ...                     ...                  ...              ...
# 2024-04-29       102.571429             0.043175        81.142857
# 2024-04-30       103.500000             0.033816        81.357143
# 2024-05-02       104.571429             0.042350        81.571429
# 2024-05-03       105.642857             0.031778        81.642857
# 2024-05-04       106.000000             0.037736        81.642857
#
#             rolling_14_tmin_pct  rolling_14_prcp  rolling_14_prcp_pct
# DATE
# 2000-01-15             0.104809         0.000000                  NaN
# 2000-01-16             0.130967         0.000000                  NaN
# 2000-01-17             0.122722         0.000000                  NaN
# 2000-01-18             0.027677         0.000000                  NaN
# 2000-01-19             0.051251         0.000000                  NaN
# ...                         ...              ...                  ...
# 2024-04-29             0.047535         0.002857                 -1.0
# 2024-04-30             0.020193         0.002857                 -1.0
# 2024-05-02             0.017513         0.002857                 -1.0
# 2024-05-03            -0.007874         0.002857                 -1.0
# 2024-05-04             0.016623         0.000714                 -1.0
#
# [8866 rows x 19 columns]

# %%
weather = weather.fillna(0)

# %%
def expand_mean(df):
    return df.expanding(1).mean()

for col in ["tmax", "tmin", "prcp"]:
    weather[f"month_avg_{col}"] = weather[col].groupby(weather.index.month, group_keys=False).apply(expand_mean)
    weather[f"day_avg_{col}"] = weather[col].groupby(weather.index.day_of_year, group_keys=False).apply(expand_mean)

# %%
weather
# Out:
#                 station                      name  prcp  tavg   tmax  tmin  \
# DATE
# 2000-01-15  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    76   91.0  64.0
# 2000-01-16  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    76   88.0  66.0
# 2000-01-17  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    76   88.0  66.0
# 2000-01-18  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    74   90.0  61.0
# 2000-01-19  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    78   89.0  63.0
# ...                 ...                       ...   ...   ...    ...   ...
# 2024-04-29  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    97  107.0  85.0
# 2024-04-30  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    98  107.0  83.0
# 2024-05-02  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    95  109.0  83.0
# 2024-05-03  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    97  109.0  81.0
# 2024-05-04  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    97  110.0  83.0
#
#             target  rolling_3_tmax  rolling_3_tmax_pct  rolling_3_tmin  ...  \
# DATE                                                                    ...
# 2000-01-15    88.0       90.333333            0.007380       64.000000  ...
# 2000-01-16    88.0       89.666667           -0.018587       64.666667  ...
# 2000-01-17    90.0       89.000000           -0.011236       65.333333  ...
# 2000-01-18    89.0       88.666667            0.015038       64.333333  ...
# 2000-01-19    91.0       89.000000            0.000000       63.333333  ...
# ...            ...             ...                 ...             ...  ...
# 2024-04-29   107.0      107.666667           -0.006192       84.000000  ...
# 2024-04-30   109.0      107.333333           -0.003106       84.000000  ...
# 2024-05-02   109.0      107.666667            0.012384       83.666667  ...
# 2024-05-03   110.0      108.333333            0.006154       82.333333  ...
# 2024-05-04   110.0      109.333333            0.006098       82.333333  ...
#
#             rolling_14_tmin  rolling_14_tmin_pct  rolling_14_prcp  \
# DATE
# 2000-01-15        57.928571             0.104809         0.000000
# 2000-01-16        58.357143             0.130967         0.000000
# 2000-01-17        58.785714             0.122722         0.000000
# 2000-01-18        59.357143             0.027677         0.000000
# 2000-01-19        59.928571             0.051251         0.000000
# ...                     ...                  ...              ...
# 2024-04-29        81.142857             0.047535         0.002857
# 2024-04-30        81.357143             0.020193         0.002857
# 2024-05-02        81.571429             0.017513         0.002857
# 2024-05-03        81.642857            -0.007874         0.002857
# 2024-05-04        81.642857             0.016623         0.000714
#
#             rolling_14_prcp_pct  month_avg_tmax  day_avg_tmax  month_avg_tmin  \
# DATE
# 2000-01-15                  0.0       91.000000         91.00       64.000000
# 2000-01-16                  0.0       89.500000         88.00       65.000000
# 2000-01-17                  0.0       89.000000         88.00       65.333333
# 2000-01-18                  0.0       89.250000         90.00       64.250000
# 2000-01-19                  0.0       89.200000         89.00       64.000000
# ...                         ...             ...           ...             ...
# 2024-04-29                 -1.0      101.168449        104.04       76.159091
# 2024-04-30                 -1.0      101.176235        104.12       76.168224
# 2024-05-02                 -1.0      103.014765        103.48       79.204027
# 2024-05-03                 -1.0      103.022788        103.08       79.206434
# 2024-05-04                 -1.0      103.032129        102.44       79.211513
#
#             day_avg_tmin  month_avg_prcp  day_avg_prcp
# DATE
# 2000-01-15         64.00        0.000000        0.0000
# 2000-01-16         66.00        0.000000        0.0000
# 2000-01-17         66.00        0.000000        0.0000
# 2000-01-18         61.00        0.000000        0.0000
# 2000-01-19         63.00        0.000000        0.0000
# ...                  ...             ...           ...
# 2024-04-29         78.64        0.030829        0.0004
# 2024-04-30         78.32        0.030788        0.1056
# 2024-05-02         78.64        0.039128        0.0000
# 2024-05-03         77.24        0.039075        0.1364
# 2024-05-04         78.44        0.039023        0.0104
#
# [8866 rows x 25 columns]

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])]

# %%
predictors
# Out:
# Index(['prcp', 'tavg', 'tmax', 'tmin', 'rolling_3_tmax', 'rolling_3_tmax_pct',
#        'rolling_3_tmin', 'rolling_3_tmin_pct', 'rolling_3_prcp',
#        'rolling_3_prcp_pct', 'rolling_14_tmax', 'rolling_14_tmax_pct',
#        'rolling_14_tmin', 'rolling_14_tmin_pct', 'rolling_14_prcp',
#        'rolling_14_prcp_pct', 'month_avg_tmax', 'day_avg_tmax',
#        'month_avg_tmin', 'day_avg_tmin', 'month_avg_prcp', 'day_avg_prcp'],
#       dtype='object')

# %%
predcitions = backtest(weather, rr, predictors)

# %%
mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 1.4920019552868555

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 2014-05-25   108.0   88.040791  19.959209
# 2014-05-08    81.0   99.009903  18.009903
# 2010-05-21   105.0   89.902581  15.097419
# 2014-04-08   104.0   89.569864  14.430136
# 2014-09-06    76.0   88.322578  12.322578
# ...            ...         ...        ...
# 2021-02-13    89.0   88.998530   0.001470
# 2021-10-05    90.0   90.001355   0.001355
# 2013-12-26    80.0   80.001003   0.001003
# 2013-12-27    80.0   80.001003   0.001003
# 2011-08-11    93.0   93.000237   0.000237
#
# [5230 rows x 3 columns]

# %%
weather.loc["2004-09-13":"2004-12-04"]
# Out:
#                 station                      name  prcp  tavg  tmax  tmin  \
# DATE
# 2004-09-13  IN001080500  BEGUMPET OBSERVATORY, IN  0.03    80  89.0  71.0
# 2004-09-14  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    83  91.0  71.0
# 2004-09-15  IN001080500  BEGUMPET OBSERVATORY, IN  0.03    80  90.0  73.0
# 2004-09-16  IN001080500  BEGUMPET OBSERVATORY, IN  0.03    81  90.0  71.0
# 2004-09-17  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    82  91.0  71.0
# ...                 ...                       ...   ...   ...   ...   ...
# 2004-11-30  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    72  85.0  54.0
# 2004-12-01  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    71  84.0  53.0
# 2004-12-02  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    72  85.0  55.0
# 2004-12-03  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    71  84.0  54.0
# 2004-12-04  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    71  84.0  54.0
#
#             target  rolling_3_tmax  rolling_3_tmax_pct  rolling_3_tmin  ...  \
# DATE                                                                    ...
# 2004-09-13    91.0       86.666667            0.026923       69.000000  ...
# 2004-09-14    90.0       89.000000            0.022472       69.666667  ...
# 2004-09-15    90.0       90.000000            0.000000       71.666667  ...
# 2004-09-16    91.0       90.333333           -0.003690       71.666667  ...
# 2004-09-17    93.0       90.333333            0.007380       71.666667  ...
# ...            ...             ...                 ...             ...  ...
# 2004-11-30    84.0       85.333333           -0.003906       55.666667  ...
# 2004-12-01    85.0       84.666667           -0.007874       54.666667  ...
# 2004-12-02    84.0       84.666667            0.003937       54.000000  ...
# 2004-12-03    84.0       84.333333           -0.003953       54.000000  ...
# 2004-12-04    87.0       84.333333           -0.003953       54.333333  ...
#
#             rolling_14_tmin  rolling_14_tmin_pct  rolling_14_prcp  \
# DATE
# 2004-09-13        70.571429             0.006073         0.263571
# 2004-09-14        70.428571             0.008114         0.263571
# 2004-09-15        70.571429             0.034413         0.265714
# 2004-09-16        70.571429             0.006073         0.267857
# 2004-09-17        70.500000             0.007092         0.267857
# ...                     ...                  ...              ...
# 2004-11-30        58.285714            -0.073529         0.000000
# 2004-12-01        57.285714            -0.074813         0.000000
# 2004-12-02        56.428571            -0.025316         0.000000
# 2004-12-03        56.071429            -0.036943         0.000000
# 2004-12-04        55.785714            -0.032010         0.000000
#
#             rolling_14_prcp_pct  month_avg_tmax  day_avg_tmax  month_avg_tmin  \
# DATE
# 2004-09-13            -0.886179       88.849624          90.2       71.684211
# 2004-09-14            -1.000000       88.865672          91.0       71.679104
# 2004-09-15            -0.887097       88.874074          91.4       71.688889
# 2004-09-16            -0.888000       88.882353          89.8       71.683824
# 2004-09-17            -1.000000       88.897810          91.4       71.678832
# ...                         ...             ...           ...             ...
# 2004-11-30             0.000000       86.733333          85.0       62.366667
# 2004-12-01             0.000000       85.360000          84.4       57.456000
# 2004-12-02             0.000000       85.357143          85.2       57.436508
# 2004-12-03             0.000000       85.346457          86.0       57.409449
# 2004-12-04             0.000000       85.335938          86.0       57.382812
#
#             day_avg_tmin  month_avg_prcp  day_avg_prcp
# DATE
# 2004-09-13          71.2        0.118872         0.012
# 2004-09-14          71.6        0.117985         0.000
# 2004-09-15          72.6        0.117333         0.006
# 2004-09-16          73.8        0.116691         0.010
# 2004-09-17          73.0        0.115839         0.004
# ...                  ...             ...           ...
# 2004-11-30          58.6        0.000267         0.000
# 2004-12-01          59.2        0.000000         0.000
# 2004-12-02          58.6        0.000000         0.000
# 2004-12-03          57.8        0.000000         0.000
# 2004-12-04          58.8        0.000000         0.000
#
# [83 rows x 25 columns]

# %%
predictions["diff"].round().value_counts().sort_index().plot()
# Out:
# <Axes: >

# %%
weather["tmax"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather["tmin"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather["prcp"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather["target"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather
# Out:
#                 station                      name  prcp  tavg   tmax  tmin  \
# DATE
# 2000-01-15  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    76   91.0  64.0
# 2000-01-16  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    76   88.0  66.0
# 2000-01-17  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    76   88.0  66.0
# 2000-01-18  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    74   90.0  61.0
# 2000-01-19  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    78   89.0  63.0
# ...                 ...                       ...   ...   ...    ...   ...
# 2024-04-29  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    97  107.0  85.0
# 2024-04-30  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    98  107.0  83.0
# 2024-05-02  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    95  109.0  83.0
# 2024-05-03  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    97  109.0  81.0
# 2024-05-04  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    97  110.0  83.0
#
#             target  rolling_3_tmax  rolling_3_tmax_pct  rolling_3_tmin  ...  \
# DATE                                                                    ...
# 2000-01-15    88.0       90.333333            0.007380       64.000000  ...
# 2000-01-16    88.0       89.666667           -0.018587       64.666667  ...
# 2000-01-17    90.0       89.000000           -0.011236       65.333333  ...
# 2000-01-18    89.0       88.666667            0.015038       64.333333  ...
# 2000-01-19    91.0       89.000000            0.000000       63.333333  ...
# ...            ...             ...                 ...             ...  ...
# 2024-04-29   107.0      107.666667           -0.006192       84.000000  ...
# 2024-04-30   109.0      107.333333           -0.003106       84.000000  ...
# 2024-05-02   109.0      107.666667            0.012384       83.666667  ...
# 2024-05-03   110.0      108.333333            0.006154       82.333333  ...
# 2024-05-04   110.0      109.333333            0.006098       82.333333  ...
#
#             rolling_14_tmin  rolling_14_tmin_pct  rolling_14_prcp  \
# DATE
# 2000-01-15        57.928571             0.104809         0.000000
# 2000-01-16        58.357143             0.130967         0.000000
# 2000-01-17        58.785714             0.122722         0.000000
# 2000-01-18        59.357143             0.027677         0.000000
# 2000-01-19        59.928571             0.051251         0.000000
# ...                     ...                  ...              ...
# 2024-04-29        81.142857             0.047535         0.002857
# 2024-04-30        81.357143             0.020193         0.002857
# 2024-05-02        81.571429             0.017513         0.002857
# 2024-05-03        81.642857            -0.007874         0.002857
# 2024-05-04        81.642857             0.016623         0.000714
#
#             rolling_14_prcp_pct  month_avg_tmax  day_avg_tmax  month_avg_tmin  \
# DATE
# 2000-01-15                  0.0       91.000000         91.00       64.000000
# 2000-01-16                  0.0       89.500000         88.00       65.000000
# 2000-01-17                  0.0       89.000000         88.00       65.333333
# 2000-01-18                  0.0       89.250000         90.00       64.250000
# 2000-01-19                  0.0       89.200000         89.00       64.000000
# ...                         ...             ...           ...             ...
# 2024-04-29                 -1.0      101.168449        104.04       76.159091
# 2024-04-30                 -1.0      101.176235        104.12       76.168224
# 2024-05-02                 -1.0      103.014765        103.48       79.204027
# 2024-05-03                 -1.0      103.022788        103.08       79.206434
# 2024-05-04                 -1.0      103.032129        102.44       79.211513
#
#             day_avg_tmin  month_avg_prcp  day_avg_prcp
# DATE
# 2000-01-15         64.00        0.000000        0.0000
# 2000-01-16         66.00        0.000000        0.0000
# 2000-01-17         66.00        0.000000        0.0000
# 2000-01-18         61.00        0.000000        0.0000
# 2000-01-19         63.00        0.000000        0.0000
# ...                  ...             ...           ...
# 2024-04-29         78.64        0.030829        0.0004
# 2024-04-30         78.32        0.030788        0.1056
# 2024-05-02         78.64        0.039128        0.0000
# 2024-05-03         77.24        0.039075        0.1364
# 2024-05-04         78.44        0.039023        0.0104
#
# [8866 rows x 25 columns]

# %%
weather.loc["2024-04-13":"2024-04-23"]
# Out:
#                 station                      name  prcp  tavg   tmax  tmin  \
# DATE
# 2024-04-13  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    85   94.0  77.0
# 2024-04-14  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    91   94.0  80.0
# 2024-04-15  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    93   94.0  80.0
# 2024-04-16  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    97   94.0  80.0
# 2024-04-17  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    96   94.0  80.0
# 2024-04-18  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    95   94.0  80.0
# 2024-04-19  IN001080500  BEGUMPET OBSERVATORY, IN  0.03    93  105.0  83.0
# 2024-04-20  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    88  104.0  83.0
# 2024-04-21  IN001080500  BEGUMPET OBSERVATORY, IN  0.01    92  102.0  79.0
# 2024-04-22  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    93  104.0  81.0
# 2024-04-23  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    94  104.0  80.0
#
#             target  rolling_3_tmax  rolling_3_tmax_pct  rolling_3_tmin  ...  \
# DATE                                                                    ...
# 2024-04-13    94.0       96.000000           -0.020833       77.000000  ...
# 2024-04-14    94.0       94.666667           -0.007042       78.000000  ...
# 2024-04-15    94.0       94.000000            0.000000       79.000000  ...
# 2024-04-16    94.0       94.000000            0.000000       80.000000  ...
# 2024-04-17    94.0       94.000000            0.000000       80.000000  ...
# 2024-04-18   105.0       94.000000            0.000000       80.000000  ...
# 2024-04-19   104.0       97.666667            0.075085       81.000000  ...
# 2024-04-20   102.0      101.000000            0.029703       82.000000  ...
# 2024-04-21   104.0      103.666667           -0.016077       81.666667  ...
# 2024-04-22   104.0      103.333333            0.006452       81.000000  ...
# 2024-04-23   104.0      103.333333            0.006452       80.000000  ...
#
#             rolling_14_tmin  rolling_14_tmin_pct  rolling_14_prcp  \
# DATE
# 2024-04-13        78.357143            -0.017320         0.000000
# 2024-04-14        78.642857             0.017257         0.000000
# 2024-04-15        78.928571             0.013575         0.000000
# 2024-04-16        79.071429             0.011743         0.000000
# 2024-04-17        79.214286             0.009919         0.000000
# 2024-04-18        79.214286             0.009919         0.000000
# 2024-04-19        79.357143             0.045905         0.002143
# 2024-04-20        79.642857             0.042152         0.002143
# 2024-04-21        79.428571            -0.005396         0.002857
# 2024-04-22        79.357143             0.020702         0.002857
# 2024-04-23        79.571429             0.005386         0.002857
#
#             rolling_14_prcp_pct  month_avg_tmax  day_avg_tmax  month_avg_tmin  \
# DATE
# 2024-04-13                  0.0      101.161202         99.84       76.053279
# 2024-04-14                  0.0      101.151432        100.32       76.058663
# 2024-04-15                  0.0      101.141689        100.24       76.064033
# 2024-04-16                  0.0      101.131973        100.48       76.069388
# 2024-04-17                  0.0      101.122283        101.32       76.074728
# 2024-04-18                  0.0      101.112619        101.80       76.080054
# 2024-04-19                 13.0      101.117886        102.40       76.089431
# 2024-04-20                 -1.0      101.121786        102.16       76.098782
# 2024-04-21                  2.5      101.122973        102.48       76.102703
# 2024-04-22                 -1.0      101.126856        102.44       76.109312
# 2024-04-23                 -1.0      101.130728        102.76       76.114555
#
#             day_avg_tmin  month_avg_prcp  day_avg_prcp
# DATE
# 2024-04-13         74.84        0.031448        0.0852
# 2024-04-14         75.48        0.031405        0.0048
# 2024-04-15         75.84        0.031362        0.0120
# 2024-04-16         76.84        0.031320        0.0728
# 2024-04-17         77.20        0.031277        0.0036
# 2024-04-18         77.28        0.031235        0.0424
# 2024-04-19         76.92        0.031233        0.0076
# 2024-04-20         77.32        0.031191        0.0008
# 2024-04-21         76.68        0.031162        0.0020
# 2024-04-22         77.20        0.031120        0.0064
# 2024-04-23         76.92        0.031078        0.0216
#
# [11 rows x 25 columns]

# %%
weather
# Out:
#                 station                      name  prcp  tavg   tmax  tmin  \
# DATE
# 2000-01-15  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    76   91.0  64.0
# 2000-01-16  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    76   88.0  66.0
# 2000-01-17  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    76   88.0  66.0
# 2000-01-18  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    74   90.0  61.0
# 2000-01-19  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    78   89.0  63.0
# ...                 ...                       ...   ...   ...    ...   ...
# 2024-04-29  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    97  107.0  85.0
# 2024-04-30  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    98  107.0  83.0
# 2024-05-02  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    95  109.0  83.0
# 2024-05-03  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    97  109.0  81.0
# 2024-05-04  IN001080500  BEGUMPET OBSERVATORY, IN   0.0    97  110.0  83.0
#
#             target  rolling_3_tmax  rolling_3_tmax_pct  rolling_3_tmin  ...  \
# DATE                                                                    ...
# 2000-01-15    88.0       90.333333            0.007380       64.000000  ...
# 2000-01-16    88.0       89.666667           -0.018587       64.666667  ...
# 2000-01-17    90.0       89.000000           -0.011236       65.333333  ...
# 2000-01-18    89.0       88.666667            0.015038       64.333333  ...
# 2000-01-19    91.0       89.000000            0.000000       63.333333  ...
# ...            ...             ...                 ...             ...  ...
# 2024-04-29   107.0      107.666667           -0.006192       84.000000  ...
# 2024-04-30   109.0      107.333333           -0.003106       84.000000  ...
# 2024-05-02   109.0      107.666667            0.012384       83.666667  ...
# 2024-05-03   110.0      108.333333            0.006154       82.333333  ...
# 2024-05-04   110.0      109.333333            0.006098       82.333333  ...
#
#             rolling_14_tmin  rolling_14_tmin_pct  rolling_14_prcp  \
# DATE
# 2000-01-15        57.928571             0.104809         0.000000
# 2000-01-16        58.357143             0.130967         0.000000
# 2000-01-17        58.785714             0.122722         0.000000
# 2000-01-18        59.357143             0.027677         0.000000
# 2000-01-19        59.928571             0.051251         0.000000
# ...                     ...                  ...              ...
# 2024-04-29        81.142857             0.047535         0.002857
# 2024-04-30        81.357143             0.020193         0.002857
# 2024-05-02        81.571429             0.017513         0.002857
# 2024-05-03        81.642857            -0.007874         0.002857
# 2024-05-04        81.642857             0.016623         0.000714
#
#             rolling_14_prcp_pct  month_avg_tmax  day_avg_tmax  month_avg_tmin  \
# DATE
# 2000-01-15                  0.0       91.000000         91.00       64.000000
# 2000-01-16                  0.0       89.500000         88.00       65.000000
# 2000-01-17                  0.0       89.000000         88.00       65.333333
# 2000-01-18                  0.0       89.250000         90.00       64.250000
# 2000-01-19                  0.0       89.200000         89.00       64.000000
# ...                         ...             ...           ...             ...
# 2024-04-29                 -1.0      101.168449        104.04       76.159091
# 2024-04-30                 -1.0      101.176235        104.12       76.168224
# 2024-05-02                 -1.0      103.014765        103.48       79.204027
# 2024-05-03                 -1.0      103.022788        103.08       79.206434
# 2024-05-04                 -1.0      103.032129        102.44       79.211513
#
#             day_avg_tmin  month_avg_prcp  day_avg_prcp
# DATE
# 2000-01-15         64.00        0.000000        0.0000
# 2000-01-16         66.00        0.000000        0.0000
# 2000-01-17         66.00        0.000000        0.0000
# 2000-01-18         61.00        0.000000        0.0000
# 2000-01-19         63.00        0.000000        0.0000
# ...                  ...             ...           ...
# 2024-04-29         78.64        0.030829        0.0004
# 2024-04-30         78.32        0.030788        0.1056
# 2024-05-02         78.64        0.039128        0.0000
# 2024-05-03         77.24        0.039075        0.1364
# 2024-05-04         78.44        0.039023        0.0104
#
# [8866 rows x 25 columns]
